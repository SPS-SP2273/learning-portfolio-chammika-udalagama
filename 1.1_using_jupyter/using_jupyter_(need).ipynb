# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Getting ready

# %% [markdown]
# print('HEllo World')

# %% [markdown]
# This is some code to calculate: $y=x^2$
#
# # Heading
#
# ## Sub heading
#
# 1. *Hahahah** This is wooowooo of cool.
#     - Sub list
#       - abc
#       - efg
# 2. *Hahaha** This is wooowooo of cool.
# 3. *Hahaha** This is wooowooo of cool.
#     - Sub list
#     - abc
#     - efg
# 4. *Hahaha**
# 5. *Hahaha** This is wooowooo of cool.
#     - Sub list
#     - abc
#     - efg
# 6. *Hahaha** This is wooowooo of cool.
# 7. *Hahaha** This is wooowooo of cool.
#
# ```python
# print('Hello World!')
# ```

# %% [markdown]
# <!--  -->

# %% [markdown]
# This is a [link](https://nus.edu.sg/)

# %% [markdown]
# ![](https://nus.edu.sg/images/default-source/corporate/homepage-refresh/20260116/feature_banner.jpg?t=1768550111)

# %% [markdown]
# $$
# x = \dfrac{\displaystyle \int f(x) dx}{y^2}
# $$

# %%
import numpy
import matplotlib as plt

# %%
# !pwd
# Out:
# /Users/chammika/Documents/learning-portfolio-chammika-udalagama/1.1_using_jupyter

# %%
# %%timeit

x= []
x = x + [1]
x = x + [2]
x = x + [3]
x
# Out:
# 98.4 ns ± 0.54 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# %lsmagic

# %%
x=100000_0000

# %%
print(x)
# Out:
# 1000000000
